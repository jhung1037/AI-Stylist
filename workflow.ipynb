# %% [markdown]
# # AI Fashion Stylist
#
# * Utilised **Cohere LLM** and **Weaviate VectorDB** to provide personalized fashion advice
# * Analyses a user's request and matching them with relevant clothing items based on the domain knowledge from the Hugging Face dataset
# * Generates a descriptive response detailing the recommended outfit, along with an example image created by **AI Horde**, offering a visual representation of the suggested ensemble

# %% [markdown]
# ### Requirements

# %%
# %pip install datasets
# %pip install cohere
# %pip install weaviate-client
# %pip install horde_sdk

# %%
import cohere
import weaviate
from datasets import load_dataset

cohere.__version__, weaviate.__version__
# Out:
# ('5.5.4', '4.6.3')

# %% [markdown]
# ### Authentication Setup

# %%
# import os

# os.environ["COHERE_APIKEY"] = "PUT_YOUR_COHERE_APIKEY_HERE"
# os.environ["WEAVIATE_URL"] = "PUT_YOUR_WEAVIATE_URL_HERE"
# os.environ["WEAVIATE_APIKEY"] = "PUT_YOUR_WEAVIATE_APIKEY_HERE"

# %% [markdown]
# ### Connect to WCS

# %%
import os
from weaviate.auth import AuthApiKey
from dotenv import load_dotenv

load_dotenv()
client = weaviate.connect_to_wcs(
    cluster_url = os.environ["WEAVIATE_URL"],
    auth_credentials = AuthApiKey(os.environ["WEAVIATE_APIKEY"]),
    headers = {
        "X-Cohere-Api-Key": os.environ["COHERE_APIKEY"]
    }
)

# %% [markdown]
# ### Load dataset

# %%
dataset = load_dataset("neuralwork/fashion-style-instruct")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'completion', 'context'],
#         num_rows: 3193
#     })
# })

# %%
import pprint
pprint.pp(dataset["train"][0])
# Out:
# {'input': "I'm a tall, athletic man with broad shoulders and a narrow waist. I "
#           'prefer sharp, tailored suits that highlight my V-shaped torso.',
#  'completion': 'Outfit Combination 1:\n'
#                '- Top: Fitted white linen shirt\n'
#                '- Bottom: Slim-fit beige chinos\n'
#                '- Shoe: Brown leather loafers\n'
#                '- Accessories: Brown woven belt, aviator sunglasses\n'
#                '\n'
#                'Outfit Combination 2:\n'
#                '- Top: Light blue oxford button-down shirt\n'
#                '- Bottom: Navy blue tailored trousers\n'
#                '- Shoe: Tan leather brogues\n'
#                '- Accessories: Navy blue patterned pocket square, silver '
#                'wristwatch\n'
#                '\n'
#                'Outfit Combination 3:\n'
#                '- Top: Light gray tailored blazer\n'
#                '- Bottom: Dark wash denim jeans\n'
#                '- Shoe: White canvas sneakers\n'
#                '- Accessories: Black leather belt, silver pendant necklace\n'
#                '\n'
#                'Outfit Combination 4:\n'
#                '- Top: Navy blue polo shirt\n'
#                '- Bottom: Khaki shorts\n'
#                '- Shoe: Brown leather sandals\n'
#                '- Accessories: Navy blue baseball cap, woven brown bracelet\n'
#                '\n'
#                'Outfit Combination 5:\n'
#                '- Top: Light pink dress shirt (with rolled-up sleeves)\n'
#                '- Bottom: Charcoal gray dress pants\n'
#                '- Shoe: Black monk strap shoes\n'
#                '- Accessories: Black leather belt, silver tie clip',
#  'context': "I'm going to a nature retreat."}

# %% [markdown]
# ### Configure vectorizer

# %%
from weaviate.classes.config import Configure

# %%
# client.collections.delete("Advisor")
client.collections.create(
    "Advisor",
    vectorizer_config = Configure.Vectorizer.text2vec_cohere(),
)

# %% [markdown]
# ### Import Data

# %%
advisor_data = client.collections.get("Advisor")

# %%
with advisor_data.batch.dynamic() as batch:
    for src_obj in dataset["train"]:
        weaviate_obj = {
            "traits": src_obj["input"],
            "combinations": src_obj["completion"],
            "occasion": src_obj["context"]
        }
        batch.add_object(properties = weaviate_obj)

len(dataset["train"]), len(advisor_data)
# Out:
# (3193, 3193)

# %% [markdown]
# ### Query from DB

# %%
query = "I am a skinny guy attending a wedding ceremony"
response = advisor_data.query.hybrid(
    query = query,
    limit = 5
)

retrieve = ""
for obj in response.objects:
    retrieve += str(obj.properties["combinations"])

print(len(response.objects))
# Out:
# 5

# %% [markdown]
# ### Generate response

# %%
co = cohere.Client(os.environ["COHERE_APIKEY"])
response = co.chat(
    message = f"""DATA: {retrieve}\n\n
                Base on the DATA and the user's request: {query}, designe ONE outfit suggestion.
                Output Format Example:
                    - Top: Fitted navy blue button-down shirt.
                    - Bottom: Dark wash slim fit jeans.
                    - Shoes: Brown leather loafers.
                    - Accessories: A sleek silver watch and a brown leather belt.""",
    max_tokens = 250
)

# %%
pprint.pp(response.text)
# Out:
# ('Here is an outfit suggestion for a skinny guy attending a wedding '
#  'ceremony: \n'
#  '\n'
#  '- Top: Slim-fit light blue dress shirt, with the sleeves rolled up to just '
#  'below the elbow. \n'
#  '- Bottom: Dark navy tailored trousers with a subtle pinstripe pattern. \n'
#  '- Shoes: Brown leather monk strap shoes with a cap toe design. \n'
#  '- Accessories: A navy blue braided leather belt, and a silver watch with a '
#  'blue face to match the shirt. \n'
#  '\n'
#  'This outfit provides a sleek and stylish look, balancing a skinny frame with '
#  'well-fitted pieces. The light blue shirt adds a touch of color and '
#  'freshness, while the dark navy trousers create a slimming effect. The brown '
#  'leather accessories bring warmth and elegance to the ensemble. \n'
#  '\n'
#  "Remember to ensure the fit is just right, and you'll look fantastic at the "
#  'wedding!')

# %% [markdown]
# ### Visual suggestion

# %%
import PIL
from horde_sdk.ai_horde_api import AIHordeAPISimpleClient
from horde_sdk.ai_horde_api.apimodels import ImageGenerateAsyncRequest

image_generate_async_request = ImageGenerateAsyncRequest(
    apikey="0000000000",
    prompt=f"Draw a model illustration base on the fashion styling advice {response.text}",
    models=["Deliberate"]
)

simple_client = AIHordeAPISimpleClient()
status_response, job_id = simple_client.image_generate_request(image_generate_async_request)

image: PIL.Image.Image = simple_client.download_image_from_generation(status_response.generations[0])
image
# Out:
# 2024-06-04 17:08:38.473 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:image_generate_request:781 - Requesting 1 images.
# 2024-06-04 17:08:38.487 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_do_request_with_check:648 - Submitting request: {'trusted_workers': False, 'slow_workers': True, 'workers': [], 'worker_blacklist': [], 'models': ['Deliberate'], 'dry_run': False, 'accept': <GenericAcceptTypes.json: 'application/json'>, 'client_agent': 'horde_sdk:v0.11.0:https://githib.com/haidra-org/horde-sdk', 'prompt': "Draw a model illustration base on the fashion styling advice Here is an outfit suggestion for a skinny guy attending a wedding ceremony: \n\n- Top: Slim-fit light blue dress shirt, with the sleeves rolled up to just below the elbow. \n- Bottom: Dark navy tailored trousers with a subtle pinstripe pattern. \n- Shoes: Brown leather monk strap shoes with a cap toe design. \n- Accessories: A navy blue braided leather belt, and a silver watch with a blue face to match the shirt. \n\nThis outfit provides a sleek and stylish look, balancing a skinny frame with well-fitted pieces. The light blue shirt adds a touch of color and freshness, while the dark navy trousers create a slimming effect. The brown leather accessories bring warmth and elegance to the ensemble. \n\nRemember to ensure the fit is just right, and you'll look fantastic at the wedding!", 'params': None, 'nsfw': True, 'censor_nsfw': False, 'r2': True, 'shared': False, 'replacement_filter': True, 'source_processing': <KNOWN_SOURCE_PROCESSING.txt2img: 'txt2img'>} with timeout 1170
# 2024-06-04 17:08:42.528 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_initial_response:510 - Response received: message='' id_=b0ce8791-52bf-491a-bc86-92acb97e15bb kudos=8.0 warnings=None
# 2024-06-04 17:08:42.937 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:558 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:08:42.939 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:559 - b0ce8791-52bf-491a-bc86-92acb97e15bb: {'finished': 0, 'processing': 0, 'restarted': 0, 'waiting': 1, 'done': False, 'faulted': False, 'wait_time': 0, 'queue_position': 0, 'kudos': 1.0, 'is_possible': True}
# 2024-06-04 17:08:47.394 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:08:51.492 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:08:55.597 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:08:59.724 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:558 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:08:59.725 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:559 - b0ce8791-52bf-491a-bc86-92acb97e15bb: {'finished': 0, 'processing': 0, 'restarted': 0, 'waiting': 1, 'done': False, 'faulted': False, 'wait_time': 334, 'queue_position': 134, 'kudos': 1.0, 'is_possible': True}
# 2024-06-04 17:09:03.825 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:08.230 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:12.324 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:16.515 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:20.911 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:558 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:20.912 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:559 - b0ce8791-52bf-491a-bc86-92acb97e15bb: {'finished': 0, 'processing': 0, 'restarted': 0, 'waiting': 1, 'done': False, 'faulted': False, 'wait_time': 135, 'queue_position': 103, 'kudos': 1.0, 'is_possible': True}
# 2024-06-04 17:09:25.001 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:29.111 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:33.335 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:37.928 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:42.041 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:558 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:42.044 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:559 - b0ce8791-52bf-491a-bc86-92acb97e15bb: {'finished': 0, 'processing': 1, 'restarted': 0, 'waiting': 0, 'done': False, 'faulted': False, 'wait_time': 13, 'queue_position': 0, 'kudos': 1.0, 'is_possible': True}
# 2024-06-04 17:09:46.291 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: b0ce8791-52bf-491a-bc86-92acb97e15bb, is_possible: True
# 2024-06-04 17:09:46.295 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:568 - Job finished and available on the server: b0ce8791-52bf-491a-bc86-92acb97e15bb
# 2024-06-04 17:09:46.381 | COMPLETE | horde_sdk.ai_horde_api.ai_horde_clients:_do_request_with_check:720 - Request complete: b0ce8791-52bf-491a-bc86-92acb97e15bb
# 2024-06-04 17:09:46.595 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:download_image_bytes:129 - Downloaded image: https://a223539ccf6caa2d76459c9727d276e6.r2.cloudflarestorage.com/stable-horde/b4818de5-221a-4a0c-90b4-26ef96b1d5e3.webp?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=246782cc9101762ba914350d8058cd83%2F20240604%2Fauto%2Fs3%2Faws4_request&X-Amz-Date=20240604T160947Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=8e2895a145c419bad1c3154e1841ca148c3d2bb2d1296d746a0d828c4f690dea
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>

# %% [markdown]
# ### Close Client

# %%
client.close()
