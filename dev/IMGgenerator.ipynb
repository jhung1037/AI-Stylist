# %%
import PIL
from horde_sdk.ai_horde_api import AIHordeAPISimpleClient
from horde_sdk.ai_horde_api.apimodels import ImageGenerateAsyncRequest

# %%
image_generate_async_request = ImageGenerateAsyncRequest(
    apikey="0000000000",
    prompt=f"Cute pet that works in the fashion industry ready to give you advice",
    models=["Deliberate"]
)

simple_client = AIHordeAPISimpleClient()
status_response, job_id = simple_client.image_generate_request(image_generate_async_request)

image: PIL.Image.Image = simple_client.download_image_from_generation(status_response.generations[0])
image
# Out:
# 2024-06-16 21:53:58.967 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:image_generate_request:781 - Requesting 1 images.
# 2024-06-16 21:53:59.058 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_do_request_with_check:648 - Submitting request: {'trusted_workers': False, 'slow_workers': True, 'workers': [], 'worker_blacklist': [], 'models': ['Deliberate'], 'dry_run': False, 'accept': <GenericAcceptTypes.json: 'application/json'>, 'client_agent': 'horde_sdk:v0.11.1:https://githib.com/haidra-org/horde-sdk', 'prompt': 'Cute pet that works in the fashion industry ready to give you advice', 'params': None, 'nsfw': True, 'censor_nsfw': False, 'r2': True, 'shared': False, 'replacement_filter': True, 'source_processing': <KNOWN_SOURCE_PROCESSING.txt2img: 'txt2img'>} with timeout 1170
# 2024-06-16 21:54:02.788 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_initial_response:510 - Response received: message='' id_=dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823 kudos=8.0 warnings=None
# 2024-06-16 21:54:03.299 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:558 - Checked request: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823, is_possible: True
# 2024-06-16 21:54:03.303 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:559 - dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823: {'finished': 0, 'processing': 1, 'restarted': 0, 'waiting': 0, 'done': False, 'faulted': False, 'wait_time': 9, 'queue_position': 0, 'kudos': 1.0, 'is_possible': True}
# 2024-06-16 21:54:07.509 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823, is_possible: True
# 2024-06-16 21:54:11.767 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823, is_possible: True
# 2024-06-16 21:54:16.199 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:564 - Checked request: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823, is_possible: True
# 2024-06-16 21:54:16.201 | PROGRESS | horde_sdk.ai_horde_api.ai_horde_clients:_handle_progress_response:568 - Job finished and available on the server: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823
# 2024-06-16 21:54:16.714 | COMPLETE | horde_sdk.ai_horde_api.ai_horde_clients:_do_request_with_check:720 - Request complete: dcd4e00a-d4b4-43fe-8cc2-9ef71f8a9823
# 2024-06-16 21:54:16.962 | DEBUG    | horde_sdk.ai_horde_api.ai_horde_clients:download_image_bytes:129 - Downloaded image: https://a223539ccf6caa2d76459c9727d276e6.r2.cloudflarestorage.com/stable-horde/a9f3b261-a97f-4a65-bbc6-e7b41bab3bad.webp?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=246782cc9101762ba914350d8058cd83%2F20240616%2Fauto%2Fs3%2Faws4_request&X-Amz-Date=20240616T205416Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=cb39b4673aa333d512ac6058ba9122274cd12fba38da5eacf32026497ce1caec
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
